# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'D:\Chenna Kesava\Data Analytics\Databases\New_Databases\Misc\Airlines+Airports+Cancellation+Codes+&+Flights\flights.csv')
df_airlines = pd.read_csv(r'D:\Chenna Kesava\Data Analytics\Databases\New_Databases\Misc\Airlines+Airports+Cancellation+Codes+&+Flights\airlines.csv')
df_airports = pd.read_csv(r'D:\Chenna Kesava\Data Analytics\Databases\New_Databases\Misc\Airlines+Airports+Cancellation+Codes+&+Flights\airports.csv')
df_cancellation = pd.read_csv(r'D:\Chenna Kesava\Data Analytics\Databases\New_Databases\Misc\Airlines+Airports+Cancellation+Codes+&+Flights\cancellation_codes.csv')
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_44768\226097216.py:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'D:\Chenna Kesava\Data Analytics\Databases\New_Databases\Misc\Airlines+Airports+Cancellation+Codes+&+Flights\flights.csv')

# %%
df_original_cleaned = df.copy()

# %%
summary = pd.DataFrame({
    'null_count': df_original_cleaned.isna().sum(),
    'empty_string_count': (df_original_cleaned == '').sum(),
    'zero_count': (df_original_cleaned == 0).sum(),
    'null_count_percentage': df_original_cleaned.isna().mean() * 100
}) 

summary
# Out:
#                      null_count  empty_string_count  zero_count  \
# YEAR                          0                   0           0
# MONTH                         0                   0           0
# DAY                           0                   0           0
# DAY_OF_WEEK                   0                   0           0
# AIRLINE                       0                   0           0
# FLIGHT_NUMBER                 0                   0           0
# TAIL_NUMBER               14721                   0           0
# ORIGIN_AIRPORT                0                   0           0
# DESTINATION_AIRPORT           0                   0           0
# SCHEDULED_DEPARTURE           0                   0           0
# DEPARTURE_TIME            86153                   0           0
# DEPARTURE_DELAY           86153                   0      329360
# TAXI_OUT                  89047                   0           0
# WHEELS_OFF                89047                   0           0
# SCHEDULED_TIME                6                   0           0
# ELAPSED_TIME             105071                   0           0
# AIR_TIME                 105071                   0           0
# DISTANCE                      0                   0           0
# WHEELS_ON                 92513                   0           0
# TAXI_IN                   92513                   0           0
# SCHEDULED_ARRIVAL             0                   0           0
# ARRIVAL_TIME              92513                   0           0
# ARRIVAL_DELAY            105071                   0      126213
# DIVERTED                      0                   0     5803892
# CANCELLED                     0                   0     5729195
# CANCELLATION_REASON     5729195                   0           0
# AIR_SYSTEM_DELAY        4755640                   0      498613
# SECURITY_DELAY          4755640                   0     1059955
# AIRLINE_DELAY           4755640                   0      493417
# LATE_AIRCRAFT_DELAY     4755640                   0      506486
# WEATHER_DELAY           4755640                   0      998723
#
#                      null_count_percentage
# YEAR                              0.000000
# MONTH                             0.000000
# DAY                               0.000000
# DAY_OF_WEEK                       0.000000
# AIRLINE                           0.000000
# FLIGHT_NUMBER                     0.000000
# TAIL_NUMBER                       0.252978
# ORIGIN_AIRPORT                    0.000000
# DESTINATION_AIRPORT               0.000000
# SCHEDULED_DEPARTURE               0.000000
# DEPARTURE_TIME                    1.480526
# DEPARTURE_DELAY                   1.480526
# TAXI_OUT                          1.530259
# WHEELS_OFF                        1.530259
# SCHEDULED_TIME                    0.000103
# ELAPSED_TIME                      1.805629
# AIR_TIME                          1.805629
# DISTANCE                          0.000000
# WHEELS_ON                         1.589822
# TAXI_IN                           1.589822
# SCHEDULED_ARRIVAL                 0.000000
# ARRIVAL_TIME                      1.589822
# ARRIVAL_DELAY                     1.805629
# DIVERTED                          0.000000
# CANCELLED                         0.000000
# CANCELLATION_REASON              98.455357
# AIR_SYSTEM_DELAY                 81.724960
# SECURITY_DELAY                   81.724960
# AIRLINE_DELAY                    81.724960
# LATE_AIRCRAFT_DELAY              81.724960
# WEATHER_DELAY                    81.724960
